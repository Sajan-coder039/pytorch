# %%
import os
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset,DataLoader
import pandas as pd
import kagglehub

# %%
path=kagglehub.dataset_download("zalando-research/fashionmnist")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/zalando-research/fashionmnist?dataset_version_number=4...
# 100%|██████████| 68.8M/68.8M [00:00<00:00, 179MB/s]
# Extracting files...

# %%
os.listdir(path)
# Out:
# ['fashion-mnist_test.csv',
#  'train-images-idx3-ubyte',
#  't10k-labels-idx1-ubyte',
#  'train-labels-idx1-ubyte',
#  't10k-images-idx3-ubyte',
#  'fashion-mnist_train.csv']

# %%
train_df=pd.read_csv(path+"/fashion-mnist_train.csv")
test_df=pd.read_csv(path+"/fashion-mnist_test.csv")

# %%
X=train_df.drop("label",axis=1)
y=train_df['label']
X_=test_df.drop("label",axis=1)
y_=test_df["label"]

# %%
X=X/255.0
X_=X_/255.0

# %%
x_train_torch=torch.tensor(X.values,dtype=torch.float32)
x_test_torch=torch.tensor(X_.values,dtype=torch.float32)
y_train_torch=torch.tensor(y.values,dtype=torch.long)
y_test_torch=torch.tensor(y_.values,dtype=torch.long)

# %%
device="cuda" if torch.cuda.is_available() else "cpu"

# %%
x_train=x_train_torch.to(device)
y_train=y_train_torch.to(device)
x_test=x_test_torch.to(device)
y_test=y_test_torch.to(device)

# %%
class CustomDataset(Dataset):
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __len__(self):
        return self.x.shape[0]
    def __getitem__(self,index):
        return self.x[index],self.y[index]
x_train_dataset=CustomDataset(x_train,y_train)
y_test_dataset=CustomDataset(x_test,y_test)

# %%
class MYNN(nn.Module):
    def __init__(self,input_dim,output_dim,dropout,num_hidden,num_neuron):
        super().__init__()
        layers=[]
        for i in range(num_hidden):
            layers.append(nn.Linear(input_dim,num_neuron))
            layers.append(nn.BatchNorm1d(num_neuron))
            layers.append(nn.Dropout(dropout))
            layers.append(nn.ReLU())
            input_dim=num_neuron
        layers.append(nn.Linear(input_dim,output_dim))
        self.model=nn.Sequential(*layers)
    def forward(self,x):
        return self.model(x)

# %%
import torch.optim as optim

# %%
def objective(trial):
    num_hidden=trial.suggest_int("num_hidden_layers",1,6)
    num_neuron=trial.suggest_int("num_neuron",8,128,step=8)
    epochs=trial.suggest_int("epochs",10,50,step=5)
    learning_rate=trial.suggest_float("learning_rate",1e-4,1e-1,log=True)
    dropout=trial.suggest_float("dropout",0.1,0.5,step=0.1)
    batch_size=trial.suggest_int("batch_size",32,256,step=32)
    optimizer_name=trial.suggest_categorical("optimizer",["Adam","RMSprop","SGD"])
    weight_decay=trial.suggest_float("weight_decay",1e-4,1e-1,log=True)

    input_dim=784
    output_dim=10

    train_load=DataLoader(x_train_dataset,batch_size=batch_size,shuffle=True)
    test_load=DataLoader(y_test_dataset,batch_size=batch_size,shuffle=False)

    model=MYNN(input_dim,output_dim,dropout,num_hidden,num_neuron)
    model.to(device)

    criterion=nn.CrossEntropyLoss()

    if optimizer_name=="Adam":
        optimizer=optim.Adam(model.parameters(),weight_decay=weight_decay,lr=learning_rate)
    elif optimizer_name=="SGD":
        optimizer=optim.SGD(model.parameters(),weight_decay=weight_decay,lr=learning_rate)
    else:
        optimizer=optim.RMSprop(model.parameters(),weight_decay=weight_decay,lr=learning_rate)
    for epoch in range(epochs):
        for x,y in train_load:
            x,y=x.to(device),y.to(device)
            out=model(x)
            loss=criterion(out,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    model.eval()
    total=0
    correct=0
    with torch.no_grad():
        for x_tes,y_tes in test_load:
            x_tes,y_tes=x_tes.to(device),y_tes.to(device)
            outputs=model(x_tes)
            _,predicted=torch.max(outputs,1)
            total+=y_tes.size(0)
            correct+=(predicted==y_tes).sum().item()
        accuracy=correct/total
    return accuracy

# %%
import optuna

# %%
study=optuna.create_study(direction="maximize")
study.optimize(objective,n_trials=50)
# Out:
# [I 2025-12-29 17:17:48,359] A new study created in memory with name: no-name-5ae315ed-27d3-43ca-ba66-64451fde5408
# [I 2025-12-29 17:18:28,474] Trial 0 finished with value: 0.7951 and parameters: {'num_hidden_layers': 1, 'num_neuron': 64, 'epochs': 45, 'learning_rate': 0.010025564996630303, 'dropout': 0.5, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.00640704984969735}. Best is trial 0 with value: 0.7951.
# [I 2025-12-29 17:20:03,888] Trial 1 finished with value: 0.7521 and parameters: {'num_hidden_layers': 1, 'num_neuron': 48, 'epochs': 30, 'learning_rate': 0.004213344212114724, 'dropout': 0.5, 'batch_size': 32, 'optimizer': 'RMSprop', 'weight_decay': 0.02805901748663848}. Best is trial 0 with value: 0.7951.
# [I 2025-12-29 17:20:24,011] Trial 2 finished with value: 0.8638 and parameters: {'num_hidden_layers': 3, 'num_neuron': 40, 'epochs': 20, 'learning_rate': 0.0007935587500282578, 'dropout': 0.4, 'batch_size': 224, 'optimizer': 'Adam', 'weight_decay': 0.00012606510396789887}. Best is trial 2 with value: 0.8638.
# [I 2025-12-29 17:21:40,950] Trial 3 finished with value: 0.8774 and parameters: {'num_hidden_layers': 3, 'num_neuron': 112, 'epochs': 45, 'learning_rate': 0.007353156883244824, 'dropout': 0.5, 'batch_size': 96, 'optimizer': 'SGD', 'weight_decay': 0.00015372288768051272}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:22:24,581] Trial 4 finished with value: 0.8317 and parameters: {'num_hidden_layers': 6, 'num_neuron': 64, 'epochs': 25, 'learning_rate': 0.005148878026956959, 'dropout': 0.30000000000000004, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0008651655302631671}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:22:56,448] Trial 5 finished with value: 0.7232 and parameters: {'num_hidden_layers': 5, 'num_neuron': 48, 'epochs': 25, 'learning_rate': 0.00826434450925795, 'dropout': 0.30000000000000004, 'batch_size': 224, 'optimizer': 'RMSprop', 'weight_decay': 0.002396613111975995}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:23:38,675] Trial 6 finished with value: 0.7606 and parameters: {'num_hidden_layers': 5, 'num_neuron': 88, 'epochs': 35, 'learning_rate': 0.07913514625891473, 'dropout': 0.2, 'batch_size': 224, 'optimizer': 'SGD', 'weight_decay': 0.06708428836363456}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:24:29,336] Trial 7 finished with value: 0.5477 and parameters: {'num_hidden_layers': 6, 'num_neuron': 104, 'epochs': 40, 'learning_rate': 0.00198059425618509, 'dropout': 0.5, 'batch_size': 256, 'optimizer': 'RMSprop', 'weight_decay': 0.02859008616266029}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:25:38,723] Trial 8 finished with value: 0.8666 and parameters: {'num_hidden_layers': 5, 'num_neuron': 32, 'epochs': 40, 'learning_rate': 0.002773601396461943, 'dropout': 0.1, 'batch_size': 128, 'optimizer': 'SGD', 'weight_decay': 0.0252846167940197}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:26:25,781] Trial 9 finished with value: 0.7566 and parameters: {'num_hidden_layers': 3, 'num_neuron': 64, 'epochs': 50, 'learning_rate': 0.0003960662856589473, 'dropout': 0.5, 'batch_size': 224, 'optimizer': 'SGD', 'weight_decay': 0.020921515329302337}. Best is trial 3 with value: 0.8774.
# [I 2025-12-29 17:26:46,150] Trial 10 finished with value: 0.8785 and parameters: {'num_hidden_layers': 2, 'num_neuron': 128, 'epochs': 10, 'learning_rate': 0.057872169764452065, 'dropout': 0.4, 'batch_size': 64, 'optimizer': 'SGD', 'weight_decay': 0.00010718008574198239}. Best is trial 10 with value: 0.8785.
# [I 2025-12-29 17:27:06,519] Trial 11 finished with value: 0.8784 and parameters: {'num_hidden_layers': 2, 'num_neuron': 128, 'epochs': 10, 'learning_rate': 0.052498150143472075, 'dropout': 0.4, 'batch_size': 64, 'optimizer': 'SGD', 'weight_decay': 0.00012968487548774922}. Best is trial 10 with value: 0.8785.
# [I 2025-12-29 17:27:43,511] Trial 12 finished with value: 0.8769 and parameters: {'num_hidden_layers': 2, 'num_neuron': 128, 'epochs': 10, 'learning_rate': 0.09550667431484987, 'dropout': 0.4, 'batch_size': 32, 'optimizer': 'SGD', 'weight_decay': 0.00041322485314727896}. Best is trial 10 with value: 0.8785.
# [I 2025-12-29 17:28:03,344] Trial 13 finished with value: 0.8769 and parameters: {'num_hidden_layers': 2, 'num_neuron': 128, 'epochs': 10, 'learning_rate': 0.02799243254352999, 'dropout': 0.4, 'batch_size': 64, 'optimizer': 'SGD', 'weight_decay': 0.0003347606640970217}. Best is trial 10 with value: 0.8785.
# [I 2025-12-29 17:28:25,481] Trial 14 finished with value: 0.884 and parameters: {'num_hidden_layers': 2, 'num_neuron': 96, 'epochs': 15, 'learning_rate': 0.028557416590978706, 'dropout': 0.4, 'batch_size': 96, 'optimizer': 'SGD', 'weight_decay': 0.0008859037538548366}. Best is trial 14 with value: 0.884.
# [I 2025-12-29 17:28:43,910] Trial 15 finished with value: 0.8291 and parameters: {'num_hidden_layers': 1, 'num_neuron': 8, 'epochs': 15, 'learning_rate': 0.01543099293072599, 'dropout': 0.2, 'batch_size': 96, 'optimizer': 'SGD', 'weight_decay': 0.0015936984908352058}. Best is trial 14 with value: 0.884.
# [I 2025-12-29 17:29:14,674] Trial 16 finished with value: 0.8783 and parameters: {'num_hidden_layers': 4, 'num_neuron': 88, 'epochs': 20, 'learning_rate': 0.028846246410569574, 'dropout': 0.30000000000000004, 'batch_size': 128, 'optimizer': 'SGD', 'weight_decay': 0.00729290730731869}. Best is trial 14 with value: 0.884.
# [I 2025-12-29 17:29:36,792] Trial 17 finished with value: 0.8782 and parameters: {'num_hidden_layers': 2, 'num_neuron': 104, 'epochs': 15, 'learning_rate': 0.02957698238049883, 'dropout': 0.4, 'batch_size': 96, 'optimizer': 'SGD', 'weight_decay': 0.0004560678626714278}. Best is trial 14 with value: 0.884.
# [I 2025-12-29 17:30:21,744] Trial 18 finished with value: 0.8475 and parameters: {'num_hidden_layers': 4, 'num_neuron': 80, 'epochs': 15, 'learning_rate': 0.0011428195763590787, 'dropout': 0.2, 'batch_size': 64, 'optimizer': 'RMSprop', 'weight_decay': 0.0009687489770416601}. Best is trial 14 with value: 0.884.
# [I 2025-12-29 17:30:44,200] Trial 19 finished with value: 0.8859 and parameters: {'num_hidden_layers': 2, 'num_neuron': 112, 'epochs': 20, 'learning_rate': 0.000145080282857193, 'dropout': 0.30000000000000004, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0046017255368937275}. Best is trial 19 with value: 0.8859.
# [I 2025-12-29 17:31:07,901] Trial 20 finished with value: 0.8627 and parameters: {'num_hidden_layers': 1, 'num_neuron': 112, 'epochs': 25, 'learning_rate': 0.00012101842694342302, 'dropout': 0.1, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.009828632831297018}. Best is trial 19 with value: 0.8859.
# [I 2025-12-29 17:31:33,762] Trial 21 finished with value: 0.8812 and parameters: {'num_hidden_layers': 2, 'num_neuron': 112, 'epochs': 20, 'learning_rate': 0.00010323706450781142, 'dropout': 0.30000000000000004, 'batch_size': 128, 'optimizer': 'Adam', 'weight_decay': 0.004252551943504955}. Best is trial 19 with value: 0.8859.
# [I 2025-12-29 17:32:03,695] Trial 22 finished with value: 0.8868 and parameters: {'num_hidden_layers': 3, 'num_neuron': 96, 'epochs': 20, 'learning_rate': 0.00010457846045065865, 'dropout': 0.30000000000000004, 'batch_size': 128, 'optimizer': 'Adam', 'weight_decay': 0.00386958370684131}. Best is trial 22 with value: 0.8868.
# [I 2025-12-29 17:32:42,862] Trial 23 finished with value: 0.8875 and parameters: {'num_hidden_layers': 3, 'num_neuron': 88, 'epochs': 30, 'learning_rate': 0.00026846022176255064, 'dropout': 0.2, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0027180159712123556}. Best is trial 23 with value: 0.8875.
# [I 2025-12-29 17:33:20,989] Trial 24 finished with value: 0.8901 and parameters: {'num_hidden_layers': 3, 'num_neuron': 80, 'epochs': 30, 'learning_rate': 0.00024595553130432444, 'dropout': 0.2, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0029182153021335634}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:33:58,668] Trial 25 finished with value: 0.8856 and parameters: {'num_hidden_layers': 4, 'num_neuron': 80, 'epochs': 30, 'learning_rate': 0.0002642447957198501, 'dropout': 0.2, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0022470095422821978}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:34:37,745] Trial 26 finished with value: 0.8783 and parameters: {'num_hidden_layers': 3, 'num_neuron': 80, 'epochs': 35, 'learning_rate': 0.0002655247452502183, 'dropout': 0.2, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.01301290232514974}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:35:22,530] Trial 27 finished with value: 0.8744 and parameters: {'num_hidden_layers': 3, 'num_neuron': 72, 'epochs': 35, 'learning_rate': 0.0003937206657912724, 'dropout': 0.1, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0034025385278981975}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:36:13,743] Trial 28 finished with value: 0.8861 and parameters: {'num_hidden_layers': 4, 'num_neuron': 96, 'epochs': 30, 'learning_rate': 0.0007391197394013188, 'dropout': 0.2, 'batch_size': 128, 'optimizer': 'Adam', 'weight_decay': 0.002116730983537351}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:36:47,606] Trial 29 finished with value: 0.8853 and parameters: {'num_hidden_layers': 3, 'num_neuron': 56, 'epochs': 30, 'learning_rate': 0.00023607103100223777, 'dropout': 0.1, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0013242570867512658}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:37:19,397] Trial 30 finished with value: 0.8864 and parameters: {'num_hidden_layers': 4, 'num_neuron': 72, 'epochs': 25, 'learning_rate': 0.0001830004758315502, 'dropout': 0.2, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0071124386814661695}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:37:50,765] Trial 31 finished with value: 0.8847 and parameters: {'num_hidden_layers': 4, 'num_neuron': 72, 'epochs': 25, 'learning_rate': 0.00018147095377902118, 'dropout': 0.2, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.005708730245557565}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:38:22,922] Trial 32 finished with value: 0.882 and parameters: {'num_hidden_layers': 3, 'num_neuron': 88, 'epochs': 25, 'learning_rate': 0.0004530875905707273, 'dropout': 0.2, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.008902904898878787}. Best is trial 24 with value: 0.8901.
# [I 2025-12-29 17:39:07,253] Trial 33 finished with value: 0.8905 and parameters: {'num_hidden_layers': 4, 'num_neuron': 96, 'epochs': 35, 'learning_rate': 0.00017306208321602628, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.016343993478118334}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:39:46,780] Trial 34 finished with value: 0.8379 and parameters: {'num_hidden_layers': 3, 'num_neuron': 96, 'epochs': 40, 'learning_rate': 0.0006032372386465646, 'dropout': 0.30000000000000004, 'batch_size': 256, 'optimizer': 'Adam', 'weight_decay': 0.051496031411345226}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:40:43,246] Trial 35 finished with value: 0.8358 and parameters: {'num_hidden_layers': 5, 'num_neuron': 104, 'epochs': 35, 'learning_rate': 0.0014146694172199944, 'dropout': 0.30000000000000004, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.017105263387802244}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:41:51,206] Trial 36 finished with value: 0.8789 and parameters: {'num_hidden_layers': 3, 'num_neuron': 88, 'epochs': 45, 'learning_rate': 0.00010115994585834014, 'dropout': 0.30000000000000004, 'batch_size': 128, 'optimizer': 'Adam', 'weight_decay': 0.03830787736311218}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:42:29,383] Trial 37 finished with value: 0.8874 and parameters: {'num_hidden_layers': 4, 'num_neuron': 96, 'epochs': 30, 'learning_rate': 0.00031079530300697037, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0031127871610907177}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:43:08,500] Trial 38 finished with value: 0.6192 and parameters: {'num_hidden_layers': 5, 'num_neuron': 120, 'epochs': 30, 'learning_rate': 0.0005343687207410359, 'dropout': 0.2, 'batch_size': 224, 'optimizer': 'RMSprop', 'weight_decay': 0.08999130448375654}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:43:48,572] Trial 39 finished with value: 0.8626 and parameters: {'num_hidden_layers': 4, 'num_neuron': 56, 'epochs': 35, 'learning_rate': 0.001103013315044148, 'dropout': 0.1, 'batch_size': 224, 'optimizer': 'Adam', 'weight_decay': 0.002875264980228906}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:44:39,538] Trial 40 finished with value: 0.887 and parameters: {'num_hidden_layers': 4, 'num_neuron': 80, 'epochs': 40, 'learning_rate': 0.0003302525747393623, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.001710228152695403}. Best is trial 33 with value: 0.8905.
# [I 2025-12-29 17:45:30,939] Trial 41 finished with value: 0.8928 and parameters: {'num_hidden_layers': 4, 'num_neuron': 80, 'epochs': 40, 'learning_rate': 0.0003251140308364834, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0015048326400664443}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:46:33,813] Trial 42 finished with value: 0.8886 and parameters: {'num_hidden_layers': 5, 'num_neuron': 88, 'epochs': 45, 'learning_rate': 0.00018431523800772833, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.000613342927035069}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:48:02,187] Trial 43 finished with value: 0.8771 and parameters: {'num_hidden_layers': 6, 'num_neuron': 64, 'epochs': 50, 'learning_rate': 0.00018876021713471158, 'dropout': 0.30000000000000004, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.00023925738897867887}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:49:00,163] Trial 44 finished with value: 0.8863 and parameters: {'num_hidden_layers': 5, 'num_neuron': 80, 'epochs': 45, 'learning_rate': 0.00016979930499999744, 'dropout': 0.30000000000000004, 'batch_size': 224, 'optimizer': 'RMSprop', 'weight_decay': 0.0005127660554672015}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:49:56,264] Trial 45 finished with value: 0.8867 and parameters: {'num_hidden_layers': 5, 'num_neuron': 88, 'epochs': 40, 'learning_rate': 0.00069273027146991, 'dropout': 0.2, 'batch_size': 192, 'optimizer': 'Adam', 'weight_decay': 0.0006137453850445236}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:50:55,173] Trial 46 finished with value: 0.8167 and parameters: {'num_hidden_layers': 5, 'num_neuron': 56, 'epochs': 45, 'learning_rate': 0.00318646815886936, 'dropout': 0.4, 'batch_size': 224, 'optimizer': 'Adam', 'weight_decay': 0.0012366323256086712}. Best is trial 41 with value: 0.8928.
# [I 2025-12-29 17:52:14,551] Trial 47 finished with value: 0.8973 and parameters: {'num_hidden_layers': 6, 'num_neuron': 104, 'epochs': 45, 'learning_rate': 0.00021326420310533226, 'dropout': 0.2, 'batch_size': 160, 'optimizer': 'Adam', 'weight_decay': 0.0007143925115484014}. Best is trial 47 with value: 0.8973.
# [I 2025-12-29 17:53:22,302] Trial 48 finished with value: 0.889 and parameters: {'num_hidden_layers': 6, 'num_neuron': 104, 'epochs': 45, 'learning_rate': 0.0001387031151989305, 'dropout': 0.30000000000000004, 'batch_size': 192, 'optimizer': 'RMSprop', 'weight_decay': 0.0002118222011460373}. Best is trial 47 with value: 0.8973.
# [I 2025-12-29 17:54:48,075] Trial 49 finished with value: 0.8813 and parameters: {'num_hidden_layers': 6, 'num_neuron': 104, 'epochs': 50, 'learning_rate': 0.0001348486095911695, 'dropout': 0.4, 'batch_size': 160, 'optimizer': 'RMSprop', 'weight_decay': 0.00018853959786525477}. Best is trial 47 with value: 0.8973.

# %%
study.best_value
# Out:
# 0.8973

# %%
study.best_params
# Out:
# {'num_hidden_layers': 6,
#  'num_neuron': 104,
#  'epochs': 45,
#  'learning_rate': 0.00021326420310533226,
#  'dropout': 0.2,
#  'batch_size': 160,
#  'optimizer': 'Adam',
#  'weight_decay': 0.0007143925115484014}
